# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\hecto\appdata\local\temp\pip-req-build-19x07hls
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mnist1d==0.0.2.post16) (3.10.6)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\hecto\AppData\Local\Temp\pip-req-build-19x07hls'

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10

# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, 10))

# Esto es una fully connected network, tines que reemplazarla por la red convolucional que se pide en el enunciado.
# Usa mm.Conv1d para las capas convolucionales, mm.ReLU para las activaciones y mm.Flatten para aplanar la salida 
# de la última capa convolucional antes de pasarla a la capa lineal final.

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 2.085804, training error 80.25, validation loss 2.090268, validation error 80.60
# Epoch     1, training loss 1.663558, training error 66.45, validation loss 1.687741, validation error 67.70
# Epoch     2, training loss 1.434470, training error 58.40, validation loss 1.437342, validation error 60.20
# Epoch     3, training loss 1.343251, training error 54.88, validation loss 1.333810, validation error 56.20
# Epoch     4, training loss 1.346330, training error 54.35, validation loss 1.343549, validation error 55.00
# Epoch     5, training loss 1.228066, training error 49.90, validation loss 1.257116, validation error 53.40
# Epoch     6, training loss 1.096233, training error 44.50, validation loss 1.109611, validation error 46.90
# Epoch     7, training loss 1.034681, training error 43.33, validation loss 1.044387, validation error 44.70
# Epoch     8, training loss 0.960412, training error 38.40, validation loss 0.975686, validation error 39.10
# Epoch     9, training loss 0.835020, training error 33.20, validation loss 0.848377, validation error 33.90
# Epoch    10, training loss 0.779395, training error 31.70, validation loss 0.805446, validation error 34.30
# Epoch    11, training loss 0.742418, training error 28.88, validation loss 0.779696, validation error 31.10
# Epoch    12, training loss 0.660688, training error 24.45, validation loss 0.717809, validation error 28.80
# Epoch    13, training loss 0.570608, training error 21.32, validation loss 0.627820, validation error 23.70
# Epoch    14, training loss 0.505656, training error 18.53, validation loss 0.567183, validation error 21.40
# Epoch    15, training loss 0.457973, training error 17.03, validation loss 0.541908, validation error 19.90
# Epoch    16, training loss 0.418322, training error 15.93, validation loss 0.501754, validation error 19.20
# Epoch    17, training loss 0.377049, training error 14.35, validation loss 0.477710, validation error 16.50
# Epoch    18, training loss 0.299209, training error 9.68, validation loss 0.426839, validation error 14.80
# Epoch    19, training loss 0.318478, training error 11.50, validation loss 0.452414, validation error 16.80
# Epoch    20, training loss 0.256059, training error 8.80, validation loss 0.407738, validation error 13.10
# Epoch    21, training loss 0.241289, training error 8.03, validation loss 0.385894, validation error 13.40
# Epoch    22, training loss 0.254130, training error 8.88, validation loss 0.411230, validation error 13.90
# Epoch    23, training loss 0.234583, training error 8.30, validation loss 0.400664, validation error 13.10
# Epoch    24, training loss 0.232077, training error 8.07, validation loss 0.407896, validation error 13.80
# Epoch    25, training loss 0.232513, training error 8.72, validation loss 0.403065, validation error 12.50
# Epoch    26, training loss 0.211749, training error 7.20, validation loss 0.390637, validation error 13.30
# Epoch    27, training loss 0.196316, training error 6.72, validation loss 0.388337, validation error 11.70
# Epoch    28, training loss 0.226835, training error 7.78, validation loss 0.396140, validation error 11.30
# Epoch    29, training loss 0.193677, training error 6.60, validation loss 0.374279, validation error 12.10
# Epoch    30, training loss 0.168247, training error 5.47, validation loss 0.373371, validation error 10.90
# Epoch    31, training loss 0.167005, training error 5.40, validation loss 0.363255, validation error 10.80
# Epoch    32, training loss 0.178162, training error 6.32, validation loss 0.407980, validation error 12.20
# Epoch    33, training loss 0.148152, training error 4.38, validation loss 0.375531, validation error 11.00
# Epoch    34, training loss 0.152216, training error 5.22, validation loss 0.375736, validation error 10.60
# Epoch    35, training loss 0.137281, training error 4.53, validation loss 0.365357, validation error 10.50
# Epoch    36, training loss 0.140470, training error 4.45, validation loss 0.367051, validation error 10.60
# Epoch    37, training loss 0.130702, training error 4.15, validation loss 0.362665, validation error 10.30
# Epoch    38, training loss 0.125898, training error 4.20, validation loss 0.393199, validation error 11.00
# Epoch    39, training loss 0.132227, training error 4.25, validation loss 0.377398, validation error 10.60
# Epoch    40, training loss 0.109757, training error 3.57, validation loss 0.357296, validation error 10.40
# Epoch    41, training loss 0.100085, training error 3.05, validation loss 0.368032, validation error 9.50
# Epoch    42, training loss 0.099561, training error 2.88, validation loss 0.364586, validation error 9.40
# Epoch    43, training loss 0.101510, training error 3.10, validation loss 0.371779, validation error 9.70
# Epoch    44, training loss 0.094197, training error 2.72, validation loss 0.374286, validation error 10.10
# Epoch    45, training loss 0.090954, training error 2.65, validation loss 0.385304, validation error 9.90
# Epoch    46, training loss 0.090383, training error 2.70, validation loss 0.376858, validation error 10.00
# Epoch    47, training loss 0.093501, training error 2.70, validation loss 0.407213, validation error 10.60
# Epoch    48, training loss 0.089334, training error 2.75, validation loss 0.390003, validation error 9.60
# Epoch    49, training loss 0.091859, training error 3.05, validation loss 0.400295, validation error 11.10
# Epoch    50, training loss 0.092934, training error 2.85, validation loss 0.391338, validation error 10.40
# Epoch    51, training loss 0.083754, training error 2.43, validation loss 0.399704, validation error 9.70
# Epoch    52, training loss 0.078265, training error 2.28, validation loss 0.378931, validation error 9.70
# Epoch    53, training loss 0.079525, training error 2.22, validation loss 0.406344, validation error 10.60
# Epoch    54, training loss 0.075361, training error 1.97, validation loss 0.410197, validation error 10.60
# Epoch    55, training loss 0.077195, training error 2.20, validation loss 0.421497, validation error 10.30
# Epoch    56, training loss 0.072347, training error 2.00, validation loss 0.412281, validation error 10.50
# Epoch    57, training loss 0.073243, training error 2.18, validation loss 0.420735, validation error 10.00
# Epoch    58, training loss 0.070037, training error 2.15, validation loss 0.414615, validation error 10.30
# Epoch    59, training loss 0.066760, training error 1.72, validation loss 0.431004, validation error 10.10
# Epoch    60, training loss 0.062821, training error 1.55, validation loss 0.425327, validation error 9.80
# Epoch    61, training loss 0.061090, training error 1.40, validation loss 0.424864, validation error 10.00
# Epoch    62, training loss 0.061952, training error 1.62, validation loss 0.419725, validation error 9.70
# Epoch    63, training loss 0.059825, training error 1.45, validation loss 0.428707, validation error 10.30
# Epoch    64, training loss 0.059477, training error 1.43, validation loss 0.434496, validation error 10.50
# Epoch    65, training loss 0.058878, training error 1.35, validation loss 0.434917, validation error 10.20
# Epoch    66, training loss 0.057566, training error 1.38, validation loss 0.434857, validation error 9.70
# Epoch    67, training loss 0.057904, training error 1.30, validation loss 0.445841, validation error 10.40
# Epoch    68, training loss 0.058760, training error 1.35, validation loss 0.451150, validation error 10.80
# Epoch    69, training loss 0.056693, training error 1.20, validation loss 0.448542, validation error 10.20
# Epoch    70, training loss 0.055675, training error 1.32, validation loss 0.436174, validation error 10.30
# Epoch    71, training loss 0.054561, training error 1.28, validation loss 0.436430, validation error 10.20
# Epoch    72, training loss 0.053173, training error 1.22, validation loss 0.442651, validation error 10.40
# Epoch    73, training loss 0.054107, training error 1.20, validation loss 0.446192, validation error 10.00
# Epoch    74, training loss 0.054918, training error 1.32, validation loss 0.463093, validation error 10.50
# Epoch    75, training loss 0.055774, training error 1.35, validation loss 0.460098, validation error 10.50
# Epoch    76, training loss 0.052966, training error 1.30, validation loss 0.450745, validation error 10.00
# Epoch    77, training loss 0.050556, training error 1.18, validation loss 0.457995, validation error 10.00
# Epoch    78, training loss 0.049687, training error 1.12, validation loss 0.451882, validation error 10.10
# Epoch    79, training loss 0.050266, training error 1.18, validation loss 0.463051, validation error 10.50
# Epoch    80, training loss 0.048457, training error 1.03, validation loss 0.459356, validation error 10.00
# Epoch    81, training loss 0.048606, training error 1.05, validation loss 0.451255, validation error 10.10
# Epoch    82, training loss 0.048245, training error 1.03, validation loss 0.463861, validation error 10.40
# Epoch    83, training loss 0.048041, training error 1.05, validation loss 0.457226, validation error 10.00
# Epoch    84, training loss 0.047493, training error 1.00, validation loss 0.461707, validation error 10.40
# Epoch    85, training loss 0.048401, training error 1.07, validation loss 0.466112, validation error 9.80
# Epoch    86, training loss 0.047601, training error 1.05, validation loss 0.469694, validation error 10.40
# Epoch    87, training loss 0.047104, training error 1.03, validation loss 0.456107, validation error 9.90
# Epoch    88, training loss 0.046252, training error 0.88, validation loss 0.465081, validation error 10.10
# Epoch    89, training loss 0.046460, training error 1.00, validation loss 0.458943, validation error 10.20
# Epoch    90, training loss 0.046075, training error 0.97, validation loss 0.467871, validation error 10.10
# Epoch    91, training loss 0.045059, training error 0.90, validation loss 0.465210, validation error 10.10
# Epoch    92, training loss 0.044823, training error 0.80, validation loss 0.467206, validation error 10.10
# Epoch    93, training loss 0.045234, training error 0.95, validation loss 0.471435, validation error 10.00
# Epoch    94, training loss 0.044824, training error 0.93, validation loss 0.469142, validation error 10.00
# Epoch    95, training loss 0.044252, training error 0.88, validation loss 0.468047, validation error 9.70
# Epoch    96, training loss 0.044027, training error 0.95, validation loss 0.471416, validation error 9.70
# Epoch    97, training loss 0.043704, training error 0.88, validation loss 0.473071, validation error 9.90
# Epoch    98, training loss 0.043456, training error 0.78, validation loss 0.469232, validation error 10.00
# Epoch    99, training loss 0.043158, training error 0.75, validation loss 0.470423, validation error 10.20
